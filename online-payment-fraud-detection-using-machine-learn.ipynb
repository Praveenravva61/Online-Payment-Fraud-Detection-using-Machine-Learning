# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/online-payment-fraud-detection/onlinefraud.csv

# %% [markdown]
# # import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score as ras

# %%
df= pd.read_csv("/kaggle/input/online-payment-fraud-detection/onlinefraud.csv")
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %% [markdown]
# # Visualizations

# %%
sns.countplot(x= "type", data = df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.barplot(x= "type", y= "amount", data= df)
# Out:
# <Axes: xlabel='type', ylabel='amount'>

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
sns.barplot(x= "type", y = "isFraud", data = df)
# Out:
# <Axes: xlabel='type', ylabel='isFraud'>

# %%
cat_cols = []
for i in df.columns:
    if df[i].dtypes == "object":
        cat_cols.append(i)

# %%
cat_cols
# Out:
# ['type', 'nameOrig', 'nameDest']

# %% [markdown]
# # Preprocessing

# %%
le= LabelEncoder()
for i in df[cat_cols]:
    df[i]=le.fit_transform(df[i])

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df
# Out:
#          step  type      amount  nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64    757869      170136.00       160296.36
# 1           1     3     1864.28   2188998       21249.00        19384.72
# 2           1     4      181.00   1002156         181.00            0.00
# 3           1     1      181.00   5828262         181.00            0.00
# 4           1     3    11668.14   3445981       41554.00        29885.86
# ...       ...   ...         ...       ...            ...             ...
# 6362615   743     1   339682.13   5651847      339682.13            0.00
# 6362616   743     4  6311409.28   1737278     6311409.28            0.00
# 6362617   743     1  6311409.28    533958     6311409.28            0.00
# 6362618   743     4   850002.52   2252932      850002.52            0.00
# 6362619   743     1   850002.52    919229      850002.52            0.00
#
#          nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot= True, cmap = 'BrBG', fmt= ".2f", linewidth = 2)
# Out:
# <Axes: >

# %%
x= df.drop(["nameOrig","nameDest","isFraud","isFlaggedFraud"],axis = 1)
y = df['isFraud']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.8, random_state = 25)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import joblib

models = [
    LogisticRegression(max_iter=1000),
    RandomForestClassifier(n_estimators=7, criterion="entropy", random_state=25),
    XGBClassifier(eval_metric='logloss')
]

for model in models:
    model.fit(x_train, y_train)

    model_name = model.__class__.__name__
    print(f"\nModel: {model_name}")

    # Predictions
    train_preds = model.predict(x_train)
    valid_preds = model.predict(x_test)

    train_probs = model.predict_proba(x_train)[:, 1]
    valid_probs = model.predict_proba(x_test)[:, 1]

    # Metrics
    print("Training Accuracy:", round(accuracy_score(y_train, train_preds), 4))
    print("Validation Accuracy:", round(accuracy_score(y_test, valid_preds), 4))
    print("Precision:", round(precision_score(y_test, valid_preds, zero_division=0), 4))
    print("Recall:", round(recall_score(y_test, valid_preds, zero_division=0), 4))
    print("F1 Score:", round(f1_score(y_test, valid_preds, zero_division=0), 4))
    print("ROC-AUC:", round(roc_auc_score(y_test, valid_probs), 4))

    print("-" * 60)

    # 🔹 SAVE MODEL
    filename = f"{model_name}_fraud_model.pkl"
    joblib.dump(model, filename)
    print(f"✅ Model saved as: {filename}")
# Out:
# Model: LogisticRegression
# Training Accuracy: 0.9991
# Validation Accuracy: 0.9991
# Precision: 0.7975
# Recall: 0.4198
# F1 Score: 0.55
# ROC-AUC: 0.9087
# ------------------------------------------------------------
# ✅ Model saved as: LogisticRegression_fraud_model.pkl
#
# Model: RandomForestClassifier
# Training Accuracy: 1.0
# Validation Accuracy: 0.9997
# Precision: 0.9671
# Recall: 0.8096
# F1 Score: 0.8814
# ROC-AUC: 0.9649
# ------------------------------------------------------------
# ✅ Model saved as: RandomForestClassifier_fraud_model.pkl
#
# Model: XGBClassifier
# Training Accuracy: 0.9989
# Validation Accuracy: 0.9988
# Precision: 0.5658
# Recall: 0.4455
# F1 Score: 0.4985
# ROC-AUC: 0.7717
# ------------------------------------------------------------
# ✅ Model saved as: XGBClassifier_fraud_model.pkl

# %% [markdown]
# # Best model performed model is RandomForestClassifier

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = ConfusionMatrixDisplay.from_estimator(models[1], x_test, y_test)
